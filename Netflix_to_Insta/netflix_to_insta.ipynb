# %%
import os

from netflix_text import *
from netflix_image import *


# 지금 많이 찾는
rec_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkdJ&qvt=0&query=%EB%84%B7%ED%94%8C%EB%A6%AD%EC%8A%A4%20%EC%B6%94%EC%B2%9C'
#주간 순위
rank_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkdJ&qvt=0&query=%EB%84%B7%ED%94%8C%EB%A6%AD%EC%8A%A4%20%EC%A3%BC%EA%B0%84%20%EC%88%9C%EC%9C%84'
# 신작
new_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkdJ&qvt=0&query=%EB%84%B7%ED%94%8C%EB%A6%AD%EC%8A%A4%20%EC%8B%A0%EC%9E%91'
# 오리지널
ori_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkdJ&qvt=0&query=%EB%84%B7%ED%94%8C%EB%A6%AD%EC%8A%A4%20%EC%98%A4%EB%A6%AC%EC%A7%80%EB%84%90'

rec_list = []
rank_list = []
new_list = []
ori_list = []

movie_infos = dict()
movie_reviews = dict()
short_reviews = dict()
os.makedirs('image', exist_ok=True)

# %%
# 입력 후 함수 실행 
list_input = input('''
                    넷플릭스 검색 리스트: 
                    1. 지금 많이보는 
                    2. 주간 순위
                    3. 신작 영화/시리즈 
                ''')
while True:
    if list_input == '1':
        search_list = get_netflix_list(rec_url, rec_list)
        print('넷플릭스 지금 많이보는 영화/시리즈가 선택되었습니다.')
        info_texts = '#넷플릭스 에서 #지금많이보는 영화/시리즈를 소개할게요!! \n\n'
        break

    elif list_input == '2':
        search_list = get_netflix_list(rank_url, rank_list)
        print('넷플릭스 주간 순위가 선택되었습니다.')
        info_texts = '#넷플릭스 #주간순위 가 높은 영화/시리즈를 소개할게요!! \n\n'
        break

    elif list_input == '3':
        search_list = get_netflix_list(new_url, new_list)
        print('넷플릭스 신작 영화/시리즈가 선택되었습니다.')
        info_texts = '#넷플릭스 #신작 영화/시리즈를 소개할게요!! \n\n'
        break

    elif list_input == 'q':
        search_list = []
        print('실행을 종료하였습니다.')
        break

    else:
        # search_list = get_netflix_list(ori_url, ori_list)
        print('1~3번 사이에서 선택해주세요.')
        list_input = input('''
                    넷플릭스 검색 리스트: 
                    1. 지금 많이보는 
                    2. 주간 순위
                    3. 신작 영화/시리즈 
                ''')
        
for i in search_list:
    try:
        info = get_netflix_info(i)
        movie_infos[i] = info
        info_text = write_text(i, info)
        info_texts = info_texts + info_text
        
        review = get_netflix_review(i)
        comment = get_netflix_comment(i)
        movie_reviews[i] = review + comment
        get_netflix_image(i)
        short_review = review_gen(movie_reviews[i])
        # top_3 = top_k_emotions(i, threshold=0.5, k=3)
        if list_input == '4':
            insta_netflix(i, short_review, ori='y')
        else:
            insta_netflix(i, short_review)
        
    except:
        continue

try:
    make_first_page(list_input)
    print('\n게시물 올라갈 캡션 내용입니다.\n')
    print(info_texts)
    print("저장된 게시물과 텍스트를 확인 후 업로드를 진행해 주세요.")

except:
    print('종료 되었습니다.')
# Out:
# 넷플릭스 주간 순위가 선택되었습니다.
# 베테랑2의 정보를 저장했습니다.
# 베테랑2의 리뷰를 저장했습니다.
# 이미지 저장 완료: image/poster_20250211/img_베테랑2.jpg
# 베테랑2, 액션과 가족애의 조화!
# 아마존 활명수의 정보를 저장했습니다.
# 아마존 활명수의 리뷰를 저장했습니다.
# 이미지 저장 완료: image/poster_20250211/img_아마존 활명수.jpg
# 가족과 함께 보면 좋은 유치한 코미디 영화!
# 히트맨의 정보를 저장했습니다.
# 히트맨의 리뷰를 저장했습니다.
# 이미지 저장 완료: image/poster_20250211/img_히트맨.jpg
# 재미있는 B급 액션 코미디 영화!
# 백 인 액션의 정보를 저장했습니다.
# 백 인 액션의 리뷰를 저장했습니다.
# 이미지 저장 완료: image/poster_20250211/img_백 인 액션.jpg
# 가족과 함께 가볍게 볼만한 액션 코미디!
# 트랜스포머: 비스트의 서막의 정보를 저장했습니다.
# 트랜스포머: 비스트의 서막의 리뷰를 저장했습니다.
# 이미지 저장 완료: image/poster_20250211/img_트랜스포머 비스트의 서막.jpg
# 트랜스포머 비스트의 서막, 기대와 아쉬움이 공존하는 액션!
# 장사리 : 잊혀진 영웅들의 정보를 저장했습니다.
# 장사리 : 잊혀진 영웅들의 리뷰를 저장했습니다.
# 이미지 저장 완료: image/poster_20250211/img_장사리  잊혀진 영웅들.jpg
# 대한민국 청년들의 희생을 그린 전쟁 드라마.
# 파일럿의 정보를 저장했습니다.
# 파일럿의 리뷰를 저장했습니다.
# 이미지 저장 완료: image/poster_20250211/img_파일럿.jpg
# 조정석의 웃음과 감동 가득한 영화.
# 센티넬의 정보를 저장했습니다.
# 센티넬의 리뷰를 저장했습니다.
# 이미지 저장 완료: image/poster_20250211/img_센티넬.jpg
# 대통령 암살 음모에 관한 스릴 넘치는 이야기!
# 도그데이즈의 정보를 저장했습니다.
# 도그데이즈의 리뷰를 저장했습니다.
# 이미지 저장 완료: image/poster_20250211/img_도그데이즈.jpg
# 강아지와 감동의 힐링 영화!
# c:\SKN Class\my_src\x proj final 참고\넷플릭스\image\poster_20250211
# 이미지를 선택하였습니다.
# 이미지가 저장되었습니다: c:\SKN Class\my_src\x proj final 참고\넷플릭스\image\insta_20250211\000_insta.jpg
#
# 게시물 올라갈 캡션 내용입니다.
#
# #넷플릭스 #주간순위 가 높은 영화/시리즈를 소개할게요!!
#
# #베테랑2
# 장르: 액션, 범죄
#
# #아마존활명수
# 장르: 코미디
#
# #히트맨
# 장르: 코미디, 액션
#
# #백인액션
# 장르: 액션, 코미디
#
# #트랜스포머:비스트의서막
# 장르: 액션, SF, 어드벤처(모험)
#
# #장사리:잊혀진영웅들
# 장르: 전쟁
#
# #파일럿
# 장르: 코미디
#
# #센티넬
# 장르: 액션, 스릴러
#
# #도그데이즈
# 장르: 드라마
#
#
# 저장된 게시물과 텍스트를 확인 후 업로드를 진행해 주세요.

# %%
# from instabot import Bot
from instagrapi import Client
import os
import time

id = "your_id"
pw = "your_password"

# 1. 인스타그램 로그인
cl = Client()
cl.login(id, pw)  # 계정 정보 입력

# 이미지가 있는 폴더 경로
add_date = time.strftime('%Y%m%d')
base_dir = os.getcwd()
image_folder = os.path.join(base_dir, 'image', f'insta_{add_date}')


# 폴더에서 이미지 파일 목록 가져오기
image_files = [f for f in os.listdir(image_folder) if f.endswith(('.jpg'))]
image_paths = []

for i in image_files:
    img = os.path.join(base_dir, 'image', f'insta_{add_date}',i)
    image_paths.append(img)


# 포스트 캡션
caption = info_texts

# 업로드 (리스트 순서대로)
try:
    cl.album_upload(image_paths, caption)
    print("게시물 업로드가 완료되었습니다!")
except Exception as e:
    print(f"업로드 실패: {e}")
# Out:
# 게시물 업로드가 완료되었습니다!
